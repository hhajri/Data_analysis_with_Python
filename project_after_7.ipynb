# %% [markdown]
# Following this link https://towardsdatascience.com/predicting-the-survival-of-titanic-passengers-30870ccc7e8 present the Titanic dataset and learn the variable survived as function of others with KN neighbor and logistic regression. Then compare them. You are asked to present your work at the end.
